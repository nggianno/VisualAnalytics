# %%
# !pip install dash-cytoscape

# %%
# import nltk
# nltk.download('stopwords')

# %%
#working example
import nltk
from wordcloud import WordCloud
from dash.dependencies import Output, Input
import dash
import dash_cytoscape as cyto 
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Output, Input
import pandas as pd 
from dash import no_update
import base64
from io import BytesIO
import re

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

data = pd.read_csv("new_emails_again.csv")
headers = pd.DataFrame(data)
del headers['Unnamed: 0']
stopwords = nltk.corpus.stopwords.words('english')
stopwords = set(stopwords)

app.layout = html.Div([
    html.Div([
        cyto.Cytoscape(
            id='org-chart',
            layout={'name': 'preset'},
            style={'width': '100%', 'height': '500px'},
            elements=[
                # Nodes elements
                {'data': {'id': 'ed', 'label': 'Sanjorge Jr. (CEO)'},
                 'position': {'x': 0, 'y': 0},
                 'locked': True
                },

                {'data': {'id': 'vp1', 'label': 'Bramar'},
                 'position': {'x': 40, 'y': 0},
                 'grabbable': False
                 },

                {'data': {'id': 'esa', 'label': 'VASCO-PAIS (ESA)'},
                 'position': {'x': -70, 'y': 50},
                'selectable': False
                },

                {'data': {'id': 'cfo', 'label': 'BARRANCO (CFO) '},
                 'position': {'x': -20, 'y': 50},
                 'selected': True
                },

                {'data': {'id': 'coo', 'label': 'STRUM (COO)'},
                 'position': {'x': 30, 'y': 50}
                },

                {'data': {'id': 'cio', 'label': 'CAMPO-CORRENTE (CIO)'},
                 'position': {'x': 80, 'y': 50}
                },
                
                {'data': {'id': 'r', 'label': 'RIBERA'},
                 'position': {'x': -20, 'y': 100}
                },
                
                {'data': {'id': 'll', 'label': 'L.LAGOS'},
                 'position': {'x': 30, 'y': 100}
                },
                
                {'data': {'id': 'pa', 'label': 'PANTANAL'},
                 'position': {'x': 80, 'y': 100}
                },
#next dept
                {'data': {'id': 'e_gm', 'label': 'Dedos'},
                 'position': {'x': 150, 'y': 0}
                },
                {'data': {'id': 'e_gm1', 'label': 'Haber'},
                 'position': {'x': 190, 'y': 0}
                },
                
                {'data': {'id': 'e_sm', 'label': 'Onda'},
                 'position': {'x': 305, 'y': 0}
                },
                {'data': {'id': 'e_a1', 'label': 'Balas'},
                 'position': {'x': 140, 'y': 50}
                },
                {'data': {'id': 'e_a2', 'label': 'Nubarron'},
                 'position': {'x': 190, 'y': 50}
                },
                {'data': {'id': 'e_a3', 'label': 'E.Orilla'},
                 'position': {'x': 230, 'y': 50}
                },
                {'data': {'id': 'e_a4', 'label': 'V.Frente'},
                 'position': {'x': 280, 'y': 50}
                },
                {'data': {'id': 'e_a5', 'label': 'Borrasca'},
                 'position': {'x': 330, 'y': 50}
                },
                {'data': {'id': 'e_a6', 'label': 'Cazar'},
                 'position': {'x': 380, 'y': 50}
                },
                {'data': {'id': 'e_b1', 'label': 'Azada'},
                 'position': {'x': 140, 'y': 100}
                },
                {'data': {'id': 'e_b2', 'label': 'B.Frente'},
                 'position': {'x': 190, 'y': 100}
                },
                {'data': {'id': 'e_b3', 'label': 'Calzas'},
                 'position': {'x': 230, 'y': 100}
                },
                {'data': {'id': 'e_b4', 'label': 'Tempestad'},
                 'position': {'x': 280, 'y': 100}
                },
                {'data': {'id': 'e_b5', 'label': 'K.Orilla'},
                 'position': {'x': 330, 'y': 100}
                },
                #IT
                {'data': {'id': 'i_gm', 'label': 'Bergen'},
                 'position': {'x': 450, 'y': 0}
                },
                {'data': {'id': 'i_gm1', 'label': 'Forluniau'},
                 'position': {'x': 490, 'y': 0}
                },
                {'data': {'id': 'i_a1', 'label': 'Baza'},
                 'position': {'x': 430, 'y': 50}
                },
                {'data': {'id': 'i_a2', 'label': 'Calixto'},
                 'position': {'x': 470, 'y': 50}
                },
                {'data': {'id': 'i_a3', 'label': 'Flecha'},
                 'position': {'x': 510, 'y': 50}
                },
                {'data': {'id': 'i_a4', 'label': 'Alcazar'},
                 'position': {'x': 550, 'y': 50}
                },
#                 #security
                
#                 {'data': {'id': 's_gm', 'label': 'Resumir'},
#                  'position': {'x': 40, 'y': 150}
#                 },
#                 {'data': {'id': 's_gm1', 'label': 'Lais'},
#                  'position': {'x': 90, 'y': 150}
#                 },
#                 {'data': {'id': 's_a1', 'label': 'Fusil'},
#                  'position': {'x': -80, 'y': 200}
#                 },
#                 {'data': {'id': 's_a2', 'label': 'V.Lagos'},
#                  'position': {'x': -40, 'y': 200}
#                 },
#                 {'data': {'id': 's_a3', 'label': 'Osvaldo'},
#                  'position': {'x': 0, 'y': 200}
#                 },
#                 {'data': {'id': 's_a4', 'label': 'Bodrogi'},
#                  'position': {'x': 40, 'y': 200}
#                 },
#                 {'data': {'id': 's_a5', 'label': 'E.Vann'},
#                  'position': {'x': 80, 'y': 200}
#                 },
#                 {'data': {'id': 's_b1', 'label': 'I.Vann'},
#                  'position': {'x': -80, 'y': 250}
#                 },
#                 {'data': {'id': 's_b1', 'label': 'Cocinaro'},
#                  'position': {'x': -40, 'y': 250}
#                 },
#                 {'data': {'id': 's_b1', 'label': 'Herrero'},
#                  'position': {'x': 0, 'y': 250}
#                 },
#                 {'data': {'id': 's_b1', 'label': 'M.Miles'},
#                  'position': {'x': 40, 'y': 250}
#                 },
#                 {'data': {'id': 's_b1', 'label': 'Ferro'},
#                  'position': {'x': 80, 'y': 250}
#                 },
                
                
                # Edge elements
                #executives
                {'data': {'source': 'ed', 'target': 'vp1', 'label': 'ED to VP1'}},
                {'data': {'source': 'ed', 'target': 'esa'}},
                {'data': {'source': 'ed', 'target': 'cfo'}},
                {'data': {'source': 'ed', 'target': 'cio'}},
                {'data': {'source': 'ed', 'target': 'coo'}},
                {'data': {'source': 'cfo', 'target': 'r'}},
                {'data': {'source': 'coo', 'target': 'll'}},
                {'data': {'source': 'cio', 'target': 'pa'}},
                #engineering
                {'data': {'source': 'e_gm', 'target': 'e_gm1'}},
                {'data': {'source': 'e_gm', 'target': 'e_a1'}},
                {'data': {'source': 'e_gm', 'target': 'e_a2'}},
                {'data': {'source': 'e_a1', 'target': 'e_b1'}},
                {'data': {'source': 'e_a2', 'target': 'e_b2'}},
                {'data': {'source': 'e_sm', 'target': 'e_a3'}},
                {'data': {'source': 'e_sm', 'target': 'e_a4'}},
                {'data': {'source': 'e_sm', 'target': 'e_a5'}},
                {'data': {'source': 'e_sm', 'target': 'e_a6'}},
                {'data': {'source': 'e_a3', 'target': 'e_b3'}},
                {'data': {'source': 'e_a4', 'target': 'e_b4'}},
                {'data': {'source': 'e_a5', 'target': 'e_b5'}},
                #IT
                {'data': {'source': 'i_gm', 'target': 'i_gm1'}},
                {'data': {'source': 'i_gm', 'target': 'i_a1'}},
                {'data': {'source': 'i_gm', 'target': 'i_a2'}},
                {'data': {'source': 'i_gm', 'target': 'i_a3'}},
                {'data': {'source': 'i_gm', 'target': 'i_a4'}},
#                 #Security
#                 {'data': {'source': 's_gm', 'target': 's_gm1'}},
#                 {'data': {'source': 's_gm', 'target': 's_a1'}},
#                 {'data': {'source': 's_gm', 'target': 's_a2'}},
#                 {'data': {'source': 's_gm', 'target': 's_a3'}},
#                 {'data': {'source': 's_gm', 'target': 's_a4'}},
#                 {'data': {'source': 's_gm', 'target': 's_a5'}},
#                 {'data': {'source': 's_a1', 'target': 's_b1'}},
#                 {'data': {'source': 's_a2', 'target': 's_b2'}},
#                 {'data': {'source': 's_a3', 'target': 's_b3'}},
#                 {'data': {'source': 's_a4', 'target': 's_b4'}},
#                 {'data': {'source': 's_a5', 'target': 's_b5'}},
            ]
        )
    ],className='six columns'),
    
    html.Div([
    html.Img(id="image_wc"),
])
    ], className='row')

def plot_wordcloud(data):
    allWords = ' '.join([word for word in headers['Subject']] )
    wc = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 115).generate(allWords)
    return wc.to_image()

@app.callback(Output('image_wc', 'src'), [Input('image_wc', 'id')])

def make_image(b):
    img = BytesIO()
    plot_wordcloud(data=headers).save(img, format='PNG')
    return 'data:image/png;base64,{}'.format(base64.b64encode(img.getvalue()).decode())

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [31/Mar/2022 15:28:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Mar/2022 15:28:48] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Mar/2022 15:28:48] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Mar/2022 15:28:50] "POST /_dash-update-component HTTP/1.1" 200 -
